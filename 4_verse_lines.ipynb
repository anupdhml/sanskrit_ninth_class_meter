# %% [markdown]
# # Verse Lines with Roots and Stems

# %% [markdown]
# ## Organizing Root Attestations Data by Verse Lines (pādas)

# %%
import pandas

# see 3_roots_with_attestations.ipynb for details on this file
df_roots = pandas.read_csv("data/roots_with_attestations.csv", keep_default_na=False)
#df_roots.head()

# %%
#df_roots_attested = df_roots[~df_roots["strong_attestations"].isna()]
#df_roots_attested = df_roots[df_roots["strong_attestations"].str.len() > 0]
df_roots_attested = df_roots.query('strong_attestations != "" or weak_attestations != ""')

df_roots_attested.head()
# Out:
#   root_guess variant_no strong_stem weak_stem  weak_only attestation_texts  \
# 1         iṣ                   iṣṇā      iṣṇī      False
# 2        ubh                  ubhnā     ubhnī      False                V.
# 4        kṣi                  kṣiṇā     kṣiṇī      False              V.B.
# 6      gr̥bh                gr̥bhṇā   gr̥bhṇī      False              V.B.
# 7         jū                   junā      junī      False                V.
#
#   language_period present_class    root  \
# 1         Earlier         ninth    iṣ 1
# 2         Earlier         ninth     ubh
# 4         Earlier         ninth     kṣī
# 6         Earlier         ninth  gr̥bhⁱ
# 7         Earlier         ninth      jū
#
#                                  strong_attestations  \
# 1                                          01.063.02
# 2                                01.063.04 04.019.04
# 4                      04.018.12 10.027.04 10.027.13
# 6  01.055.02 01.163.02 03.030.05 05.031.07 07.101...
# 7            01.027.07 01.071.06 01.186.05 07.086.07
#
#    strong_attestations_total  \
# 1                          1
# 2                          2
# 4                          3
# 6                         10
# 7                          4
#
#                                    weak_attestations  weak_attestations_total
# 1                                                                           0
# 2                                                                           0
# 4                                                                           0
# 6  09.046.04 09.106.03 10.062.01 10.062.02 10.062...                        6
# 7                                          09.079.02                        1

# %%
rv_lines = []

roots_attested = df_roots_attested.to_dict("records")

for root in roots_attested:
    rv_weak_stanza_nos = root.pop("weak_attestations").split()
    rv_strong_stanza_nos = root.pop("strong_attestations").split()   
    # FIXME just eliminate these? since these are only stanza
    root.pop("weak_attestations_total")
    root.pop("strong_attestations_total")
    
    weak_stem = root.pop("weak_stem")
    strong_stem = root.pop("strong_stem")
    
    # we set line_no to be stanza_no, to start off with
    # (will be updated to actual line_no later)
    for stanza_no in rv_weak_stanza_nos:
        rv_lines.append({"line_no": stanza_no, "stem": weak_stem, "stem_type": "weak"} | root)  
    for stanza_no in rv_strong_stanza_nos: 
        rv_lines.append({"line_no": stanza_no, "stem": strong_stem, "stem_type": "strong"} | root)

rv_lines[0]
# Out:
# {'line_no': '01.063.02',
#  'stem': 'iṣṇā',
#  'stem_type': 'strong',
#  'root_guess': 'iṣ',
#  'variant_no': '',
#  'weak_only': False,
#  'attestation_texts': '',
#  'language_period': 'Earlier',
#  'present_class': 'ninth',
#  'root': 'iṣ 1'}

# %% [markdown]
# ## Parsing Line numbers into Constituents

# %%
# "1.1.1b" > "01" "001" "02" "b"
# 01.063.02 > "01" "063" "02" ""
def parse_rv_line_no(string):
    line_no_parts = string.split(".")
    
    book = line_no_parts[0].zfill(2)
    hymn = line_no_parts[1].zfill(3)
    
    last_char = line_no_parts[2][-1]
    if last_char.isalpha(): # if pada is already present
        stanza = line_no_parts[2][:-1] # drop the last char
        pada = last_char
    else:
        stanza = line_no_parts[2]
        pada = ""

    stanza = stanza.zfill(2)

    return {
        "book"    : book,
        "hymn"    : f"{book}.{hymn}",
        "stanza"  : f"{book}.{hymn}.{stanza}",
        "pada"    : f"{book}.{hymn}.{stanza}.{pada}" if pada else ""
        #"pada_id" : pada or ''
    }    

rv_lines = [line | (parse_rv_line_no(line["line_no"])) for line in rv_lines]

rv_lines[0]
# Out:
# {'line_no': '01.063.02',
#  'stem': 'iṣṇā',
#  'stem_type': 'strong',
#  'root_guess': 'iṣ',
#  'variant_no': '',
#  'weak_only': False,
#  'attestation_texts': '',
#  'language_period': 'Earlier',
#  'present_class': 'ninth',
#  'root': 'iṣ 1',
#  'book': '01',
#  'hymn': '01.063',
#  'stanza': '01.063.02',
#  'pada': ''}

# %% [markdown]
# ## Enrching Verse Lines with Stanza Metadata

# %% [markdown]
# ### Downloading annotation data

# %%
# !mkdir -p downloads/vedaweb

# %%
import os
import requests
import time

VEDAWEB_API_URL = "https://vedaweb.uni-koeln.de/rigveda/api"

rv_stanza_nos = sorted(list(set([line["stanza"] for line in rv_lines])))

# %%
# no of stanzas for which to dowload the stanza data
len(rv_stanza_nos)
# Out:
# 814

# %%
for stanza_no in rv_stanza_nos:
    print(f"Getting data for stanza: {stanza_no}")
    
    stanza_file = f"downloads/vedaweb/{stanza_no}.json"
    if os.path.exists(stanza_file):
        # we already downloaded this stanza so continue to the next one
        continue
    
    # eg: https://vedaweb.uni-koeln.de/rigveda/api/document/id/0100102
    vedaweb_doc_id = stanza_no.replace('.', '')
    vedaweb_doc_url = f"{VEDAWEB_API_URL}/document/id/{vedaweb_doc_id}"
    
    response = requests.get(vedaweb_doc_url)
    # raises an exception on non-200 responses, since we want to know and act on it
    response.raise_for_status()
    
    with open(stanza_file, 'w') as f:
        f.write(response.text)
    
    # so that we don't hammer the api
    time.sleep(0.5)

print("Done!")
# Out:
# Getting data for stanza: 01.010.04
# Getting data for stanza: 01.010.07
# Getting data for stanza: 01.010.08
# Getting data for stanza: 01.012.01
# Getting data for stanza: 01.013.02
# Getting data for stanza: 01.013.05
# Getting data for stanza: 01.013.12
# Getting data for stanza: 01.015.02
# Getting data for stanza: 01.015.03
# Getting data for stanza: 01.017.09
# Getting data for stanza: 01.018.01
# Getting data for stanza: 01.018.04
# Getting data for stanza: 01.018.08
# Getting data for stanza: 01.023.21
# Getting data for stanza: 01.025.01
# Getting data for stanza: 01.027.07
# Getting data for stanza: 01.027.12
# Getting data for stanza: 01.028.06
# Getting data for stanza: 01.030.12
# Getting data for stanza: 01.030.14
# Getting data for stanza: 01.030.15
# Getting data for stanza: 01.031.03
# Getting data for stanza: 01.031.07
# Getting data for stanza: 01.031.08
# Getting data for stanza: 01.032.03
# Getting data for stanza: 01.032.04
# Getting data for stanza: 01.035.09
# Getting data for stanza: 01.036.03
# Getting data for stanza: 01.037.06
# Getting data for stanza: 01.037.13
# Getting data for stanza: 01.039.07
# Getting data for stanza: 01.042.05
# Getting data for stanza: 01.042.07
# Getting data for stanza: 01.042.10
# Getting data for stanza: 01.044.03
# Getting data for stanza: 01.047.02
# Getting data for stanza: 01.048.04
# Getting data for stanza: 01.048.08
# Getting data for stanza: 01.048.14
# Getting data for stanza: 01.051.03
# Getting data for stanza: 01.051.04
# Getting data for stanza: 01.051.08
# Getting data for stanza: 01.053.02
# Getting data for stanza: 01.054.07
# Getting data for stanza: 01.054.09
# Getting data for stanza: 01.055.02
# Getting data for stanza: 01.055.05
# Getting data for stanza: 01.055.07
# Getting data for stanza: 01.056.06
# Getting data for stanza: 01.059.06
# Getting data for stanza: 01.061.04
# Getting data for stanza: 01.061.13
# Getting data for stanza: 01.063.02
# Getting data for stanza: 01.063.04
# Getting data for stanza: 01.064.12
# Getting data for stanza: 01.066.10
# Getting data for stanza: 01.067.01
# Getting data for stanza: 01.068.01
# Getting data for stanza: 01.071.06
# Getting data for stanza: 01.071.10
# Getting data for stanza: 01.074.04
# Getting data for stanza: 01.077.01
# Getting data for stanza: 01.077.02
# Getting data for stanza: 01.078.04
# Getting data for stanza: 01.079.12
# Getting data for stanza: 01.080.03
# Getting data for stanza: 01.082.01
# Getting data for stanza: 01.084.03
# Getting data for stanza: 01.086.02
# Getting data for stanza: 01.089.04
# Getting data for stanza: 01.089.08
# Getting data for stanza: 01.092.04
# Getting data for stanza: 01.092.06
# Getting data for stanza: 01.093.01
# Getting data for stanza: 01.093.04
# Getting data for stanza: 01.093.06
# Getting data for stanza: 01.093.12
# Getting data for stanza: 01.094.02
# Getting data for stanza: 01.094.08
# Getting data for stanza: 01.095.08
# Getting data for stanza: 01.095.10
# Getting data for stanza: 01.102.09
# Getting data for stanza: 01.104.09
# Getting data for stanza: 01.105.15
# Getting data for stanza: 01.109.04
# Getting data for stanza: 01.110.01
# Getting data for stanza: 01.110.03
# Getting data for stanza: 01.110.08
# Getting data for stanza: 01.113.15
# Getting data for stanza: 01.114.04
# Getting data for stanza: 01.114.09
# Getting data for stanza: 01.114.11
# Getting data for stanza: 01.115.05
# Getting data for stanza: 01.116.10
# Getting data for stanza: 01.116.12
# Getting data for stanza: 01.116.14
# Getting data for stanza: 01.117.04
# Getting data for stanza: 01.117.11
# Getting data for stanza: 01.117.13
# Getting data for stanza: 01.117.19
# Getting data for stanza: 01.118.03
# Getting data for stanza: 01.119.05
# Getting data for stanza: 01.122.04
# Getting data for stanza: 01.122.09
# Getting data for stanza: 01.123.09
# Getting data for stanza: 01.123.10
# Getting data for stanza: 01.123.11
# Getting data for stanza: 01.124.03
# Getting data for stanza: 01.124.07
# Getting data for stanza: 01.125.02
# Getting data for stanza: 01.125.05
# Getting data for stanza: 01.127.04
# Getting data for stanza: 01.129.04
# Getting data for stanza: 01.130.03
# Getting data for stanza: 01.131.04
# Getting data for stanza: 01.131.07
# Getting data for stanza: 01.132.04
# Getting data for stanza: 01.133.01
# Getting data for stanza: 01.139.01
# Getting data for stanza: 01.139.07
# Getting data for stanza: 01.143.04
# Getting data for stanza: 01.146.01
# Getting data for stanza: 01.147.02
# Getting data for stanza: 01.148.04
# Getting data for stanza: 01.153.03
# Getting data for stanza: 01.155.04
# Getting data for stanza: 01.160.03
# Getting data for stanza: 01.161.02
# Getting data for stanza: 01.161.07
# Getting data for stanza: 01.161.11
# Getting data for stanza: 01.162.18
# Getting data for stanza: 01.162.19
# Getting data for stanza: 01.162.22
# Getting data for stanza: 01.163.02
# Getting data for stanza: 01.163.06
# Getting data for stanza: 01.164.16
# Getting data for stanza: 01.164.28
# Getting data for stanza: 01.164.37
# Getting data for stanza: 01.165.09
# Getting data for stanza: 01.166.06
# Getting data for stanza: 01.166.12
# Getting data for stanza: 01.168.08
# Getting data for stanza: 01.173.11
# Getting data for stanza: 01.174.02
# Getting data for stanza: 01.174.09
# Getting data for stanza: 01.179.01
# Getting data for stanza: 01.179.04
# Getting data for stanza: 01.180.04
# Getting data for stanza: 01.181.07
# Getting data for stanza: 01.182.03
# Getting data for stanza: 01.184.04
# Getting data for stanza: 01.186.03
# Getting data for stanza: 01.186.05
# Getting data for stanza: 01.186.10
# Getting data for stanza: 02.002.06
# Getting data for stanza: 02.005.07
# Getting data for stanza: 02.009.04
# Getting data for stanza: 02.011.18
# Getting data for stanza: 02.012.02
# Getting data for stanza: 02.012.03
# Getting data for stanza: 02.012.05
# Getting data for stanza: 02.013.02
# Getting data for stanza: 02.013.03
# Getting data for stanza: 02.013.04
# Getting data for stanza: 02.013.05
# Getting data for stanza: 02.013.10
# Getting data for stanza: 02.014.03
# Getting data for stanza: 02.014.04
# Getting data for stanza: 02.015.05
# Getting data for stanza: 02.015.06
# Getting data for stanza: 02.016.03
# Getting data for stanza: 02.016.06
# Getting data for stanza: 02.017.03
# Getting data for stanza: 02.017.05
# Getting data for stanza: 02.017.06
# Getting data for stanza: 02.020.04
# Getting data for stanza: 02.022.04
# Getting data for stanza: 02.024.08
# Getting data for stanza: 02.025.01
# Getting data for stanza: 02.025.02
# Getting data for stanza: 02.025.03
# Getting data for stanza: 02.025.04
# Getting data for stanza: 02.025.05
# Getting data for stanza: 02.026.02
# Getting data for stanza: 02.027.01
# Getting data for stanza: 02.030.05
# Getting data for stanza: 02.030.06
# Getting data for stanza: 02.030.07
# Getting data for stanza: 02.032.03
# Getting data for stanza: 02.032.04
# Getting data for stanza: 02.033.04
# Getting data for stanza: 02.033.08
# Getting data for stanza: 02.033.12
# Getting data for stanza: 02.033.13
# Getting data for stanza: 02.033.15
# Getting data for stanza: 02.034.12
# Getting data for stanza: 02.034.14
# Getting data for stanza: 02.036.04
# Getting data for stanza: 02.041.13
# Getting data for stanza: 02.041.19
# Getting data for stanza: 03.002.04
# Getting data for stanza: 03.003.11
# Getting data for stanza: 03.004.04
# Getting data for stanza: 03.006.02
# Getting data for stanza: 03.006.06
# Getting data for stanza: 03.006.10
# Getting data for stanza: 03.011.07
# Getting data for stanza: 03.012.06
# Getting data for stanza: 03.029.09
# Getting data for stanza: 03.029.12
# Getting data for stanza: 03.029.16
# Getting data for stanza: 03.030.05
# Getting data for stanza: 03.030.06
# Getting data for stanza: 03.030.09
# Getting data for stanza: 03.030.10
# Getting data for stanza: 03.030.12
# Getting data for stanza: 03.030.17
# Getting data for stanza: 03.031.19
# Getting data for stanza: 03.031.20
# Getting data for stanza: 03.031.21
# Getting data for stanza: 03.033.09
# Getting data for stanza: 03.034.03
# Getting data for stanza: 03.036.08
# Getting data for stanza: 03.039.07
# Getting data for stanza: 03.044.05
# Getting data for stanza: 03.045.04
# Getting data for stanza: 03.047.02
# Getting data for stanza: 03.049.02
# Getting data for stanza: 03.051.12
# Getting data for stanza: 03.053.03
# Getting data for stanza: 03.053.09
# Getting data for stanza: 03.053.10
# Getting data for stanza: 03.054.01
# Getting data for stanza: 03.054.19
# Getting data for stanza: 03.054.20
# Getting data for stanza: 03.058.03
# Getting data for stanza: 03.059.02
# Getting data for stanza: 03.060.02
# Getting data for stanza: 03.062.02
# Getting data for stanza: 04.002.20
# Getting data for stanza: 04.003.01
# Getting data for stanza: 04.004.01
# Getting data for stanza: 04.004.05
# Getting data for stanza: 04.004.06
# Getting data for stanza: 04.004.14
# Getting data for stanza: 04.007.11
# Getting data for stanza: 04.009.07
# Getting data for stanza: 04.009.08
# Getting data for stanza: 04.010.07
# Getting data for stanza: 04.015.10
# Getting data for stanza: 04.016.07
# Getting data for stanza: 04.017.10
# Getting data for stanza: 04.017.13
# Getting data for stanza: 04.018.05
# Getting data for stanza: 04.018.12
# Getting data for stanza: 04.019.03
# Getting data for stanza: 04.019.04
# Getting data for stanza: 04.019.05
# Getting data for stanza: 04.019.06
# Getting data for stanza: 04.020.09
# Getting data for stanza: 04.022.09
# Getting data for stanza: 04.022.10
# Getting data for stanza: 04.023.03
# Getting data for stanza: 04.024.06
# Getting data for stanza: 04.024.10
# Getting data for stanza: 04.025.03
# Getting data for stanza: 04.025.06
# Getting data for stanza: 04.025.07
# Getting data for stanza: 04.028.01
# Getting data for stanza: 04.028.04
# Getting data for stanza: 04.030.06
# Getting data for stanza: 04.031.11
# Getting data for stanza: 04.032.02
# Getting data for stanza: 04.035.03
# Getting data for stanza: 04.035.04
# Getting data for stanza: 04.035.06
# Getting data for stanza: 04.035.09
# Getting data for stanza: 04.036.04
# Getting data for stanza: 04.039.03
# Getting data for stanza: 04.041.07
# Getting data for stanza: 04.042.05
# Getting data for stanza: 04.042.07
# Getting data for stanza: 04.043.02
# Getting data for stanza: 04.050.09
# Getting data for stanza: 04.053.01
# Getting data for stanza: 04.053.03
# Getting data for stanza: 04.054.02
# Getting data for stanza: 04.057.07
# Getting data for stanza: 05.002.09
# Getting data for stanza: 05.003.02
# Getting data for stanza: 05.005.05
# Getting data for stanza: 05.006.09
# Getting data for stanza: 05.007.04
# Getting data for stanza: 05.020.03
# Getting data for stanza: 05.026.04
# Getting data for stanza: 05.026.08
# Getting data for stanza: 05.027.03
# Getting data for stanza: 05.028.03
# Getting data for stanza: 05.028.06
# Getting data for stanza: 05.031.01
# Getting data for stanza: 05.031.07
# Getting data for stanza: 05.031.11
# Getting data for stanza: 05.032.01
# Getting data for stanza: 05.032.11
# Getting data for stanza: 05.032.12
# Getting data for stanza: 05.034.01
# Getting data for stanza: 05.034.03
# Getting data for stanza: 05.034.05
# Getting data for stanza: 05.034.09
# Getting data for stanza: 05.040.09
# Getting data for stanza: 05.041.06
# Getting data for stanza: 05.041.10
# Getting data for stanza: 05.041.12
# Getting data for stanza: 05.041.19
# Getting data for stanza: 05.042.01
# Getting data for stanza: 05.042.09
# Getting data for stanza: 05.042.13
# Getting data for stanza: 05.043.05
# Getting data for stanza: 05.043.11
# Getting data for stanza: 05.045.06
# Getting data for stanza: 05.046.08
# Getting data for stanza: 05.049.05
# Getting data for stanza: 05.050.01
# Getting data for stanza: 05.053.16
# Getting data for stanza: 05.054.10
# Getting data for stanza: 05.054.12
# Getting data for stanza: 05.057.03
# Getting data for stanza: 05.057.07
# Getting data for stanza: 05.061.07
# Getting data for stanza: 05.075.04
# Getting data for stanza: 05.077.02
# Getting data for stanza: 05.080.04
# Getting data for stanza: 05.080.06
# Getting data for stanza: 05.082.01
# Getting data for stanza: 05.082.07
# Getting data for stanza: 05.083.03
# Getting data for stanza: 05.084.01
# Getting data for stanza: 06.001.01
# Getting data for stanza: 06.002.10
# Getting data for stanza: 06.004.03
# Getting data for stanza: 06.005.03
# Getting data for stanza: 06.008.03
# Getting data for stanza: 06.009.02
# Getting data for stanza: 06.009.03
# Getting data for stanza: 06.010.07
# Getting data for stanza: 06.013.03
# Getting data for stanza: 06.013.05
# Getting data for stanza: 06.015.09
# Getting data for stanza: 06.017.03
# Getting data for stanza: 06.018.05
# Getting data for stanza: 06.020.12
# Getting data for stanza: 06.023.08
# Getting data for stanza: 06.025.03
# Getting data for stanza: 06.028.04
# Getting data for stanza: 06.028.06
# Getting data for stanza: 06.030.02
# Getting data for stanza: 06.035.05
# Getting data for stanza: 06.044.04
# Getting data for stanza: 06.044.09
# Getting data for stanza: 06.044.18
# Getting data for stanza: 06.044.22
# Getting data for stanza: 06.044.23
# Getting data for stanza: 06.045.06
# Getting data for stanza: 06.045.14
# Getting data for stanza: 06.045.30
# Getting data for stanza: 06.047.04
# Getting data for stanza: 06.047.05
# Getting data for stanza: 06.047.12
# Getting data for stanza: 06.047.15
# Getting data for stanza: 06.048.04
# Getting data for stanza: 06.049.06
# Getting data for stanza: 06.050.08
# Getting data for stanza: 06.050.14
# Getting data for stanza: 06.052.07
# Getting data for stanza: 06.052.13
# Getting data for stanza: 06.053.04
# Getting data for stanza: 06.053.07
# Getting data for stanza: 06.053.08
# Getting data for stanza: 06.053.10
# Getting data for stanza: 06.055.05
# Getting data for stanza: 06.060.10
# Getting data for stanza: 06.060.15
# Getting data for stanza: 06.064.01
# Getting data for stanza: 06.064.02
# Getting data for stanza: 06.067.02
# Getting data for stanza: 06.068.03
# Getting data for stanza: 06.069.01
# Getting data for stanza: 06.069.04
# Getting data for stanza: 06.069.05
# Getting data for stanza: 06.069.07
# Getting data for stanza: 06.071.01
# Getting data for stanza: 06.074.01
# Getting data for stanza: 06.075.02
# Getting data for stanza: 06.075.05
# Getting data for stanza: 06.075.18
# Getting data for stanza: 07.003.01
# Getting data for stanza: 07.006.04
# Getting data for stanza: 07.007.03
# Getting data for stanza: 07.013.02
# Getting data for stanza: 07.017.01
# Getting data for stanza: 07.017.03
# Getting data for stanza: 07.018.05
# Getting data for stanza: 07.018.11
# Getting data for stanza: 07.018.18
# Getting data for stanza: 07.019.09
# Getting data for stanza: 07.022.07
# Getting data for stanza: 07.022.08
# Getting data for stanza: 07.025.02
# Getting data for stanza: 07.025.04
# Getting data for stanza: 07.026.05
# Getting data for stanza: 07.028.01
# Getting data for stanza: 07.029.04
# Getting data for stanza: 07.031.10
# Getting data for stanza: 07.032.06
# Getting data for stanza: 07.032.08
# Getting data for stanza: 07.032.09
# Getting data for stanza: 07.033.02
# Getting data for stanza: 07.033.05
# Getting data for stanza: 07.034.05
# Getting data for stanza: 07.034.06
# Getting data for stanza: 07.034.09
# Getting data for stanza: 07.034.12
# Getting data for stanza: 07.034.16
# Getting data for stanza: 07.034.22
# Getting data for stanza: 07.035.06
# Getting data for stanza: 07.036.04
# Getting data for stanza: 07.036.08
# Getting data for stanza: 07.038.04
# Getting data for stanza: 07.038.05
# Getting data for stanza: 07.039.03
# Getting data for stanza: 07.043.02
# Getting data for stanza: 07.044.05
# Getting data for stanza: 07.046.01
# Getting data for stanza: 07.053.02
# Getting data for stanza: 07.054.01
# Getting data for stanza: 07.056.12
# Getting data for stanza: 07.063.03
# Getting data for stanza: 07.065.04
# Getting data for stanza: 07.066.07
# Getting data for stanza: 07.067.10
# Getting data for stanza: 07.069.04
# Getting data for stanza: 07.069.08
# Getting data for stanza: 07.073.02
# Getting data for stanza: 07.081.01
# Getting data for stanza: 07.081.04
# Getting data for stanza: 07.082.06
# Getting data for stanza: 07.082.08
# Getting data for stanza: 07.083.04
# Getting data for stanza: 07.084.02
# Getting data for stanza: 07.084.04
# Getting data for stanza: 07.085.01
# Getting data for stanza: 07.086.03
# Getting data for stanza: 07.086.07
# Getting data for stanza: 07.090.02
# Getting data for stanza: 07.094.02
# Getting data for stanza: 07.097.02
# Getting data for stanza: 07.097.03
# Getting data for stanza: 07.099.01
# Getting data for stanza: 07.099.02
# Getting data for stanza: 07.099.03
# Getting data for stanza: 07.099.07
# Getting data for stanza: 07.100.05
# Getting data for stanza: 07.100.07
# Getting data for stanza: 07.101.03
# Getting data for stanza: 07.102.02
# Getting data for stanza: 07.103.04
# Getting data for stanza: 07.103.09
# Getting data for stanza: 07.104.01
# Getting data for stanza: 07.104.06
# Getting data for stanza: 07.104.13
# Getting data for stanza: 07.104.14
# Getting data for stanza: 08.002.11
# Getting data for stanza: 08.002.19
# Getting data for stanza: 08.003.13
# Getting data for stanza: 08.003.18
# Getting data for stanza: 08.004.06
# Getting data for stanza: 08.004.15
# Getting data for stanza: 08.004.16
# Getting data for stanza: 08.006.44
# Getting data for stanza: 08.012.11
# Getting data for stanza: 08.013.01
# Getting data for stanza: 08.013.07
# Getting data for stanza: 08.014.06
# Getting data for stanza: 08.014.14
# Getting data for stanza: 08.015.04
# Getting data for stanza: 08.015.09
# Getting data for stanza: 08.017.02
# Getting data for stanza: 08.018.11
# Getting data for stanza: 08.018.15
# Getting data for stanza: 08.018.16
# Getting data for stanza: 08.018.18
# Getting data for stanza: 08.019.20
# Getting data for stanza: 08.021.14
# Getting data for stanza: 08.023.16
# Getting data for stanza: 08.024.06
# Getting data for stanza: 08.025.13
# Getting data for stanza: 08.026.21
# Getting data for stanza: 08.027.18
# Getting data for stanza: 08.027.22
# Getting data for stanza: 08.031.05
# Getting data for stanza: 08.031.08
# Getting data for stanza: 08.031.09
# Getting data for stanza: 08.031.10
# Getting data for stanza: 08.032.11
# Getting data for stanza: 08.032.17
# Getting data for stanza: 08.033.12
# Getting data for stanza: 08.034.03
# Getting data for stanza: 08.035.10
# Getting data for stanza: 08.035.19
# Getting data for stanza: 08.036.07
# Getting data for stanza: 08.037.07
# Getting data for stanza: 08.038.08
# Getting data for stanza: 08.039.05
# Getting data for stanza: 08.039.06
# Getting data for stanza: 08.040.03
# Getting data for stanza: 08.041.08
# Getting data for stanza: 08.042.01
# Getting data for stanza: 08.044.20
# Getting data for stanza: 08.045.06
# Getting data for stanza: 08.045.09
# Getting data for stanza: 08.045.22
# Getting data for stanza: 08.048.06
# Getting data for stanza: 08.048.09
# Getting data for stanza: 08.051.06
# Getting data for stanza: 08.052.08
# Getting data for stanza: 08.052.10
# Getting data for stanza: 08.054.04
# Getting data for stanza: 08.060.01
# Getting data for stanza: 08.061.16
# Getting data for stanza: 08.062.05
# Getting data for stanza: 08.062.06
# Getting data for stanza: 08.063.03
# Getting data for stanza: 08.063.07
# Getting data for stanza: 08.064.01
# Getting data for stanza: 08.064.04
# Getting data for stanza: 08.065.05
# Getting data for stanza: 08.067.04
# Getting data for stanza: 08.067.17
# Getting data for stanza: 08.071.05
# Getting data for stanza: 08.071.15
# Getting data for stanza: 08.072.01
# Getting data for stanza: 08.073.03
# Getting data for stanza: 08.073.07
# Getting data for stanza: 08.073.10
# Getting data for stanza: 08.078.05
# Getting data for stanza: 08.079.02
# Getting data for stanza: 08.080.10
# Getting data for stanza: 08.082.06
# Getting data for stanza: 08.083.01
# Getting data for stanza: 08.083.04
# Getting data for stanza: 08.084.03
# Getting data for stanza: 08.085.02
# Getting data for stanza: 08.085.04
# Getting data for stanza: 08.088.03
# Getting data for stanza: 08.089.05
# Getting data for stanza: 08.090.02
# Getting data for stanza: 08.091.07
# Getting data for stanza: 08.093.18
# Getting data for stanza: 08.097.13
# Getting data for stanza: 08.100.06
# Getting data for stanza: 08.102.12
# Getting data for stanza: 09.001.06
# Getting data for stanza: 09.003.05
# Getting data for stanza: 09.004.04
# Getting data for stanza: 09.011.05
# Getting data for stanza: 09.011.06
# Getting data for stanza: 09.016.03
# Getting data for stanza: 09.029.04
# Getting data for stanza: 09.030.06
# Getting data for stanza: 09.036.03
# Getting data for stanza: 09.046.04
# Getting data for stanza: 09.051.01
# Getting data for stanza: 09.051.02
# Getting data for stanza: 09.055.04
# Getting data for stanza: 09.061.04
# Getting data for stanza: 09.062.18
# Getting data for stanza: 09.062.29
# Getting data for stanza: 09.065.06
# Getting data for stanza: 09.065.09
# Getting data for stanza: 09.065.28
# Getting data for stanza: 09.066.18
# Getting data for stanza: 09.067.22
# Getting data for stanza: 09.067.23
# Getting data for stanza: 09.067.24
# Getting data for stanza: 09.067.25
# Getting data for stanza: 09.067.26
# Getting data for stanza: 09.067.27
# Getting data for stanza: 09.067.31
# Getting data for stanza: 09.069.03
# Getting data for stanza: 09.070.06
# Getting data for stanza: 09.071.01
# Getting data for stanza: 09.071.02
# Getting data for stanza: 09.071.08
# Getting data for stanza: 09.074.07
# Getting data for stanza: 09.076.01
# Getting data for stanza: 09.078.01
# Getting data for stanza: 09.079.02
# Getting data for stanza: 09.081.02
# Getting data for stanza: 09.082.04
# Getting data for stanza: 09.083.01
# Getting data for stanza: 09.083.04
# Getting data for stanza: 09.084.01
# Getting data for stanza: 09.085.04
# Getting data for stanza: 09.086.16
# Getting data for stanza: 09.086.23
# Getting data for stanza: 09.088.05
# Getting data for stanza: 09.091.04
# Getting data for stanza: 09.091.05
# Getting data for stanza: 09.092.05
# Getting data for stanza: 09.094.05
# Getting data for stanza: 09.095.01
# Getting data for stanza: 09.095.02
# Getting data for stanza: 09.096.11
# Getting data for stanza: 09.097.04
# Getting data for stanza: 09.097.09
# Getting data for stanza: 09.097.30
# Getting data for stanza: 09.097.41
# Getting data for stanza: 09.097.58
# Getting data for stanza: 09.102.08
# Getting data for stanza: 09.103.02
# Getting data for stanza: 09.104.03
# Getting data for stanza: 09.106.03
# Getting data for stanza: 09.110.06
# Getting data for stanza: 10.002.04
# Getting data for stanza: 10.006.03
# Getting data for stanza: 10.006.05
# Getting data for stanza: 10.006.06
# Getting data for stanza: 10.009.07
# Getting data for stanza: 10.010.14
# Getting data for stanza: 10.012.04
# Getting data for stanza: 10.013.03
# Getting data for stanza: 10.013.04
# Getting data for stanza: 10.014.13
# Getting data for stanza: 10.015.06
# Getting data for stanza: 10.016.01
# Getting data for stanza: 10.016.06
# Getting data for stanza: 10.016.07
# Getting data for stanza: 10.016.09
# Getting data for stanza: 10.017.01
# Getting data for stanza: 10.018.11
# Getting data for stanza: 10.018.13
# Getting data for stanza: 10.021.01
# Getting data for stanza: 10.023.04
# Getting data for stanza: 10.023.05
# Getting data for stanza: 10.025.03
# Getting data for stanza: 10.025.06
# Getting data for stanza: 10.027.04
# Getting data for stanza: 10.027.13
# Getting data for stanza: 10.027.24
# Getting data for stanza: 10.028.02
# Getting data for stanza: 10.030.03
# Getting data for stanza: 10.030.05
# Getting data for stanza: 10.030.07
# Getting data for stanza: 10.030.08
# Getting data for stanza: 10.030.11
# Getting data for stanza: 10.030.15
# Getting data for stanza: 10.031.08
# Getting data for stanza: 10.031.10
# Getting data for stanza: 10.034.04
# Getting data for stanza: 10.034.08
# Getting data for stanza: 10.034.12
# Getting data for stanza: 10.034.14
# Getting data for stanza: 10.035.01
# Getting data for stanza: 10.035.02
# Getting data for stanza: 10.036.02
# Getting data for stanza: 10.036.03
# Getting data for stanza: 10.036.04
# Getting data for stanza: 10.036.05
# Getting data for stanza: 10.036.06
# Getting data for stanza: 10.036.07
# Getting data for stanza: 10.036.08
# Getting data for stanza: 10.036.09
# Getting data for stanza: 10.036.10
# Getting data for stanza: 10.036.11
# Getting data for stanza: 10.036.12
# Getting data for stanza: 10.038.02
# Getting data for stanza: 10.039.02
# Getting data for stanza: 10.039.06
# Getting data for stanza: 10.039.08
# Getting data for stanza: 10.039.11
# Getting data for stanza: 10.040.02
# Getting data for stanza: 10.040.08
# Getting data for stanza: 10.042.03
# Getting data for stanza: 10.042.04
# Getting data for stanza: 10.042.05
# Getting data for stanza: 10.042.09
# Getting data for stanza: 10.042.11
# Getting data for stanza: 10.043.05
# Getting data for stanza: 10.043.08
# Getting data for stanza: 10.043.11
# Getting data for stanza: 10.044.11
# Getting data for stanza: 10.045.06
# Getting data for stanza: 10.047.08
# Getting data for stanza: 10.048.09
# Getting data for stanza: 10.048.10
# Getting data for stanza: 10.048.11
# Getting data for stanza: 10.051.05
# Getting data for stanza: 10.053.07
# Getting data for stanza: 10.055.01
# Getting data for stanza: 10.055.03
# Getting data for stanza: 10.061.03
# Getting data for stanza: 10.062.01
# Getting data for stanza: 10.062.02
# Getting data for stanza: 10.062.03
# Getting data for stanza: 10.062.04
# Getting data for stanza: 10.062.09
# Getting data for stanza: 10.064.04
# Getting data for stanza: 10.064.07
# Getting data for stanza: 10.064.10
# Getting data for stanza: 10.064.15
# Getting data for stanza: 10.066.14
# Getting data for stanza: 10.067.06
# Getting data for stanza: 10.067.11
# Getting data for stanza: 10.067.12
# Getting data for stanza: 10.068.06
# Getting data for stanza: 10.071.04
# Getting data for stanza: 10.071.06
# Getting data for stanza: 10.073.11
# Getting data for stanza: 10.074.05
# Getting data for stanza: 10.075.05
# Getting data for stanza: 10.076.02
# Getting data for stanza: 10.076.04
# Getting data for stanza: 10.076.08
# Getting data for stanza: 10.078.08
# Getting data for stanza: 10.084.05
# Getting data for stanza: 10.085.03
# Getting data for stanza: 10.085.04
# Getting data for stanza: 10.085.14
# Getting data for stanza: 10.085.20
# Getting data for stanza: 10.085.24
# Getting data for stanza: 10.085.36
# Getting data for stanza: 10.085.42
# Getting data for stanza: 10.085.45
# Getting data for stanza: 10.086.15
# Getting data for stanza: 10.087.05
# Getting data for stanza: 10.087.07
# Getting data for stanza: 10.087.08
# Getting data for stanza: 10.087.10
# Getting data for stanza: 10.087.14
# Getting data for stanza: 10.087.25
# Getting data for stanza: 10.088.04
# Getting data for stanza: 10.088.12
# Getting data for stanza: 10.089.06
# Getting data for stanza: 10.089.07
# Getting data for stanza: 10.089.08
# Getting data for stanza: 10.091.05
# Getting data for stanza: 10.091.13
# Getting data for stanza: 10.092.12
# Getting data for stanza: 10.092.14
# Getting data for stanza: 10.095.05
# Getting data for stanza: 10.095.11
# Getting data for stanza: 10.097.22
# Getting data for stanza: 10.100.01
# Getting data for stanza: 10.100.02
# Getting data for stanza: 10.100.03
# Getting data for stanza: 10.100.04
# Getting data for stanza: 10.100.05
# Getting data for stanza: 10.100.06
# Getting data for stanza: 10.100.07
# Getting data for stanza: 10.100.08
# Getting data for stanza: 10.100.09
# Getting data for stanza: 10.100.10
# Getting data for stanza: 10.100.11
# Getting data for stanza: 10.101.02
# Getting data for stanza: 10.101.05
# Getting data for stanza: 10.101.07
# Getting data for stanza: 10.101.08
# Getting data for stanza: 10.104.10
# Getting data for stanza: 10.107.07
# Getting data for stanza: 10.110.02
# Getting data for stanza: 10.111.04
# Getting data for stanza: 10.112.08
# Getting data for stanza: 10.113.04
# Getting data for stanza: 10.113.09
# Getting data for stanza: 10.116.03
# Getting data for stanza: 10.117.02
# Getting data for stanza: 10.117.03
# Getting data for stanza: 10.117.05
# Getting data for stanza: 10.117.07
# Getting data for stanza: 10.117.09
# Getting data for stanza: 10.120.01
# Getting data for stanza: 10.120.07
# Getting data for stanza: 10.120.08
# Getting data for stanza: 10.122.01
# Getting data for stanza: 10.125.04
# Getting data for stanza: 10.125.05
# Getting data for stanza: 10.125.06
# Getting data for stanza: 10.126.02
# Getting data for stanza: 10.127.08
# Getting data for stanza: 10.128.05
# Getting data for stanza: 10.131.02
# Getting data for stanza: 10.131.06
# Getting data for stanza: 10.134.03
# Getting data for stanza: 10.134.04
# Getting data for stanza: 10.134.07
# Getting data for stanza: 10.135.03
# Getting data for stanza: 10.138.04
# Getting data for stanza: 10.138.06
# Getting data for stanza: 10.139.05
# Getting data for stanza: 10.139.06
# Getting data for stanza: 10.142.07
# Getting data for stanza: 10.143.01
# Getting data for stanza: 10.145.04
# Getting data for stanza: 10.149.01
# Getting data for stanza: 10.153.03
# Getting data for stanza: 10.160.03
# Getting data for stanza: 10.160.04
# Getting data for stanza: 10.165.03
# Getting data for stanza: 10.165.04
# Getting data for stanza: 10.171.01
# Getting data for stanza: 10.171.03
# Getting data for stanza: 10.175.01
# Getting data for stanza: 10.180.03
# Getting data for stanza: 10.188.01
# Done!

# %% [markdown]
# ### Enriching the lines with text and metrical info

# %%
import json

with open(f"data/roots_with_attested_words.json") as f:
    roots_with_attested_words = json.load(f)

# %%
# in the same folder as this notebook
import src.lib.verse_lines as verse_lines

# useful during testing to pick up changes in the file
import importlib
importlib.reload(verse_lines)

rv_lines_annotated = []
for line in rv_lines:
    # we can get multiple pada lines from a singe stanza attestation so need to use extend
    rv_lines_annotated.extend(verse_lines.annotate_line(line, roots_with_attested_words))

print(f"\nTotal number of lines: {len(rv_lines_annotated)}")

rv_lines_annotated[0] # sample
# Out:
# Total number of lines: 881
# {'line_no': '01.063.02.d',
#  'stem': 'iṣṇā',
#  'stem_type': 'strong',
#  'root_guess': 'iṣ',
#  'variant_no': '',
#  'weak_only': False,
#  'attestation_texts': '',
#  'language_period': 'Earlier',
#  'present_class': 'ninth',
#  'root': 'iṣ 1',
#  'book': '01',
#  'hymn': '01.063',
#  'stanza': '01.063.02',
#  'pada_id': 'd',
#  'pada_label': 'M',
#  'word': 'iṣṇā́si',
#  'word_position_no': 2,
#  'word_position': 'intermediate',
#  'word_gloss': '2.SG.PRS.IND.ACT',
#  'text_padapatha': 'púraḥ iṣṇā́si= puruhūta pūrvī́ḥ',
#  'text_samhitapatha': 'púra iṣṇā́si puruhūta pūrvī́ḥ',
#  'meter_scansion': 'SS LLS SSLS LL',
#  'stanza_meter': 'Triṣṭubh',
#  'stanza_strata': 'A',
#  'stanza_strata_based_on_meter_only': False,
#  'stanza_late_addition': '',
#  'hymn_absolute_no': 63,
#  'hymn_addressee': 'Indra',
#  'hymn_group': 'Hymns of Nodhas, Descendant of Gotama'}

# %% [markdown]
# ## Saving the Results

# %%
df_rv_lines = pandas.DataFrame.from_dict(rv_lines_annotated)
df_rv_lines.to_csv("data/rv_lines.csv", index=None)
df_rv_lines.head()
# Out:
#        line_no   stem stem_type root_guess variant_no  weak_only  \
# 0  01.063.02.d   iṣṇā    strong         iṣ                 False
# 1  01.063.04.b  ubhnā    strong        ubh                 False
# 2  04.019.04.c  ubhnā    strong        ubh                 False
# 3  04.018.12.d  kṣiṇā    strong        kṣi                 False
# 4  10.027.04.d  kṣiṇā    strong        kṣi                 False
#
#   attestation_texts language_period present_class  root  ...  \
# 0                           Earlier         ninth  iṣ 1  ...
# 1                V.         Earlier         ninth   ubh  ...
# 2                V.         Earlier         ninth   ubh  ...
# 3              V.B.         Earlier         ninth   kṣī  ...
# 4              V.B.         Earlier         ninth   kṣī  ...
#
#                             text_padapatha  \
# 0          púraḥ iṣṇā́si= puruhūta pūrvī́ḥ
# 1  vr̥trám yát vajrin= vr̥ṣakarman ubhnā́ḥ
# 2         dr̥ḷhā́ni aubhnāt= uśámānaḥ ójaḥ
# 3      yát prá ákṣiṇāḥ= pitáram pādagŕ̥hya
# 4     prá tám kṣiṇām= párvate-_ pādagŕ̥hya
#
#                         text_samhitapatha   meter_scansion stanza_meter  \
# 0           púra iṣṇā́si puruhūta pūrvī́ḥ   SS LLS SSLS LL   Triṣṭubh
# 1  vr̥tráṁ yád vajrin vr̥ṣakarman ubhnā́ḥ  LL L LL SSLS LL   Triṣṭubh
# 2        dr̥r̥ḷhā́ni+ aubhnād uśámāna ójo  SLLS LL SSLS LL
# 3       yát prā́kṣiṇāḥ pitáram pādagŕ̥hya   L LSL SSL LSLS   Triṣṭubh
# 4       prá táṁ kṣiṇām párvate pādagŕ̥hya  S L SL LSL LSLS   Triṣṭubh
#
#   stanza_strata stanza_strata_based_on_meter_only  \
# 0             A                             False
# 1             A                             False
# 2             S                             False
# 3             P                             False
# 4             P                             False
#
#            stanza_late_addition hymn_absolute_no  \
# 0                                             63
# 1                                             63
# 2                                            315
# 3  [Grassmann (G), Arnold (C1)]              314
# 4                 [Arnold (C1)]              853
#
#                                hymn_addressee  \
# 0                                       Indra
# 1                                       Indra
# 2                                       Indra
# 3  Dialogue Between Indra, Aditi and Vamadeva
# 4                                       Indra
#
#                               hymn_group
# 0  Hymns of Nodhas, Descendant of Gotama
# 1  Hymns of Nodhas, Descendant of Gotama
# 2                         Hymns to Indra
# 3                         Hymns to Indra
# 4                      The Vasukra Hymns
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Validation

# %% [markdown]
# ### Checking for missing roots

# %%
import numpy as np

def print_roots_attestation_info(df_roots, df_rv_lines, present_class):
    # our starting list of roots
    roots_initial = np.sort(df_roots.query(
        f"present_class == '{present_class}'"
    )["root"].unique())
    print(f"Starting list ({len(roots_initial)}):\n{roots_initial}\n")
    
    # attested roots
    roots_present = np.sort(df_rv_lines.query(
        f"present_class == '{present_class}'"
    )["root"].unique())
    print(f"Attested ({len(roots_present)}):\n{roots_present}\n")

    # missing roots
    roots_absent = np.sort(
        np.setdiff1d(roots_initial, roots_present)
    )
    print(f"Missing ({len(roots_absent)}):\n{roots_absent}\n")

# %%
print_roots_attestation_info(df_roots, df_rv_lines, "ninth")
# Out:
# Starting list (53):
# ['aś' 'aśⁱ' 'bandh' 'bhrī' 'dhu dhū' 'drū' 'dr̥' 'grath' 'gr̥' 'gr̥bhⁱ'
#  'gr̥hⁱ' 'gr̥̄ 1' 'hr̥̄' 'hvr̥ hru' 'i 2' 'iṣ 1' 'jyā' 'jñā' 'jū' 'kliś'
#  'krī' 'kuṣ' 'kṣī' 'lu' 'mathⁱ' 'mr̥d' 'mr̥̄ 1' 'muṣⁱ' 'mī 1' 'pruṣ' 'prī'
#  'pr̥̄ 1' 'puṣ' 'pū' 'ram' 'rī' 'skambhⁱ' 'spr̥' 'stambhⁱ' 'str̥̄' 'subh'
#  'sā si' 'ubh' 'uṣ' 'vli vlī' 'vr̥' 'vr̥ vr̥̄' 'śam' 'ścam' 'śrathⁱ' 'śrī'
#  'śrī 2' 'śr̥̄ 1']
#
# Attested (31):
# ['aśⁱ' 'bandh' 'gr̥bhⁱ' 'gr̥hⁱ' 'gr̥̄ 1' 'hr̥̄' 'hvr̥ hru' 'iṣ 1' 'jyā'
#  'jñā' 'jū' 'krī' 'kṣī' 'mathⁱ' 'mr̥̄ 1' 'muṣⁱ' 'mī 1' 'prī' 'pr̥̄ 1' 'pū'
#  'ram' 'rī' 'skambhⁱ' 'stambhⁱ' 'str̥̄' 'sā si' 'ubh' 'vr̥ vr̥̄' 'śrathⁱ'
#  'śrī' 'śr̥̄ 1']
#
# Missing (22):
# ['aś' 'bhrī' 'dhu dhū' 'drū' 'dr̥' 'grath' 'gr̥' 'i 2' 'kliś' 'kuṣ' 'lu'
#  'mr̥d' 'pruṣ' 'puṣ' 'spr̥' 'subh' 'uṣ' 'vli vlī' 'vr̥' 'śam' 'ścam'
#  'śrī 2']

# %%
print_roots_attestation_info(df_roots, df_rv_lines, "fifth")
# Out:
# Starting list (49):
# ['akṣ' 'ci' 'ci 1' 'dabh' 'dagh' 'dhi' 'dhr̥ṣ' 'dhū' 'du' 'dāś' 'hi' 'i 2'
#  'jagh' 'ji 2 jinv' 'kr̥' 'kṣi' 'kṣubh' 'lu' 'mi' 'mi 1' 'naś 1' 'pi'
#  'pruṣⁱ' 'pr̥' 'pr̥ 1' 'ri' 'rādh' 'r̥ 1' 'r̥dh' 'sadh' 'sagh' 'si'
#  'skabh' 'sku' 'spr̥' 'stabh' 'stigh' 'str̥' 'stu' 'su' 'takṣ' 'ti' 'tr̥p'
#  'u 1' 'vr̥' 'vr̥ vr̥̄' 'āp' 'śak' 'śru']
#
# Attested (23):
# ['ci 1' 'dabh' 'dhr̥ṣ' 'dhū' 'dāś' 'hi' 'i 2' 'ji 2 jinv' 'kr̥' 'mi 1'
#  'naś 1' 'pruṣⁱ' 'r̥ 1' 'r̥dh' 'sagh' 'spr̥' 'str̥' 'su' 'tr̥p' 'u 1'
#  'vr̥' 'śak' 'śru']
#
# Missing (26):
# ['akṣ' 'ci' 'dagh' 'dhi' 'du' 'jagh' 'kṣi' 'kṣubh' 'lu' 'mi' 'pi' 'pr̥'
#  'pr̥ 1' 'ri' 'rādh' 'sadh' 'si' 'skabh' 'sku' 'stabh' 'stigh' 'stu'
#  'takṣ' 'ti' 'vr̥ vr̥̄' 'āp']

# %% [markdown]
# TODO explain that these roots not being in RV is ok (and expected):
#
# * Some roots are attested only as weak stem before vowel (i.e no _nī_ form). e.g.:  [_uṣ_](https://vedaweb.uni-koeln.de/rigveda/view/id/09.097.39)
# * Some roots are there in later vedic texts.
# * Some roots are already marked as later language in whitney (to be found only in Classical / Epic sanskrit

# %% [markdown]
# TODO also try searching by alternate stem/root vowel forms for the missing roots (and also for the attested?), to see if there are actually recorded in those forms

# %% [markdown]
# ### Checking found word against padapatha text

# %%
# from src/lib/meter.py
from src.lib.meter import clean_lubotsky_padapatha

mismatches = []

no_of_mismatches = 0

for line in rv_lines_annotated:
    padapatha_text_cleaned = clean_lubotsky_padapatha(line["text_padapatha"])
    padapatha_parts = padapatha_text_cleaned.split(' ')
    
    word_from_padapatha = padapatha_parts[line["word_position_no"] - 1]
    
    if line["word"] != word_from_padapatha:
        no_of_mismatches += 1
        print(
            f"{line['line_no']}:{line['word_position_no']}", 
            f"({line['stem']}) {line['word']} ≠ {word_from_padapatha}",
            #f"[{padapatha_text_cleaned}]",
            f"[{line['text_padapatha']}]"
        )
        
print(f"\nFound {no_of_mismatches} mismatches.")
# Out:
# 09.104.03.a:1 (punā) punā́ta ≠ punā́tā [punā́tā+ dakṣasā́dhanam]
# 02.033.13.c:3 (vr̥ṇī) ávr̥ṇīta ≠ ávr̥ṇītā [yā́ni mánuḥ= ávr̥ṇītā+} pitā́ naḥ]
# 07.033.02.d:3 (vr̥ṇī) avr̥ṇīta ≠ avr̥ṇītā [sutā́t índraḥ= avr̥ṇītā+} vásiṣṭhān]
# 06.028.06.b:3 (kr̥ṇu) kr̥ṇutha ≠ kr̥ṇuthā [aśrīrám cit= kr̥ṇuthā+ suprátīkam]
# 01.110.03.d:3 (kr̥ṇu) akr̥ṇuta ≠ akr̥ṇutā [ékam sántam= akr̥ṇutā+} cáturvayam]
# 05.049.05.c:4 (kr̥ṇu) kr̥ṇutá ≠ kr̥ṇutā́ [áva etu ábhvam= kr̥ṇutā́+} várīyaḥ]
# 06.025.03.d:3 (kr̥ṇu) kr̥ṇuhí ≠ kr̥ṇuhī́ [jahí vŕ̥ṣṇyāni= kr̥ṇuhī́?_+} párācaḥ]
# 08.027.18.a:4 (kr̥ṇu) kr̥ṇutha ≠ kr̥ṇuthā [ájre?_ cit asmai= kr̥ṇuthā+} nyáñcanam]
# 10.067.11.a:3 (kr̥ṇu) kr̥ṇuta ≠ kr̥ṇutā [satyā́m āśíṣam= kr̥ṇutā+} vayodhaí]
# 10.078.08.a:4 (kr̥ṇu) kr̥ṇuta ≠ kr̥ṇutā [subhāgā́n naḥ= devāḥ kr̥ṇutā+ surátnān]
# 01.161.11.a:3 (kr̥ṇo) akr̥ṇotana ≠ akr̥ṇotanā [udvátsu asmai= akr̥ṇotanā+ tŕ̥ṇam]
# 08.045.22.c:3 (aśnu) aśnuhi ≠ aśnuhī [tr̥mpā́+ ví aśnuhī?_+ mádam]
# 10.066.14.d:4 (dhunu dhūnu) dhūnuta ≠ dhūnutā [asmé?_ devāsaḥ= áva dhūnutā+ vásu]
# 01.082.01.a:4 (śr̥ṇu) śr̥ṇuhí ≠ śr̥ṇuhī́ [úpa u+_ sú śr̥ṇuhī́?_+ gíraḥ]
# 01.086.02.c:2 (śr̥ṇu) śr̥ṇutá ≠ śr̥ṇutā́ [márutaḥ śr̥ṇutā́+ hávam]
# 02.041.13.b:1 (śr̥ṇu) śr̥ṇutá ≠ śr̥ṇutā́ [śr̥ṇutā́+ me-_ imám hávam]
# 04.009.07.c:2 (śr̥ṇu) śr̥ṇudhi ≠ śr̥ṇudhī [asmā́kam śr̥ṇudhī?_+ hávam]
# 06.052.07.b:1 (śr̥ṇu) śr̥ṇutá ≠ śr̥ṇutā́ [śr̥ṇutā́+ me-_ imám hávam]
# 08.003.18.d:3 (śr̥ṇu) śr̥ṇudhi ≠ śr̥ṇudhī [venáḥ ná+_ śr̥ṇudhī?_+ hávam]
# 08.013.07.b:1 (śr̥ṇu) śr̥ṇudhí ≠ śr̥ṇudhī́ [śr̥ṇudhī́?_+ jaritúḥ hávam]
# 08.052.08.d:2 (śr̥ṇu) śr̥ṇudhi ≠ śr̥ṇudhī [kaṇvavát śr̥ṇudhī?_+ hávam]
# 08.084.03.b:3 (śr̥ṇu) śr̥ṇudhí ≠ śr̥ṇudhī́ [nr̥ŕ̥n pāhi śr̥ṇudhī́?_+ gíraḥ]
# 10.030.08.d:3 (śr̥ṇu) śr̥ṇutá ≠ śr̥ṇutā́ [ā́paḥ revatīḥ= śr̥ṇutā́+} hávam me-_]
# 07.032.08.a:1 (suno) sunóta ≠ sunótā [sunótā+ somapā́vne?_]
# 09.030.06.a:1 (suno) sunóta ≠ sunótā [sunótā+ mádhumattamam]
# 09.051.02.c:1 (suno) sunóta ≠ sunótā [sunótā+ mádhumattamam]
# 06.045.14.c:3 (hinu) hinuhi ≠ hinuhī [táyā naḥ hinuhī?_+ rátham]
# 10.030.11.a:1 (hino) hinóta ≠ hinótā [hinótā+ naḥ= adhvarám devayajyā́]
#
# Found 28 mismatches.

# %% [markdown]
# Ignore cases of final vowel lengthening above (especially with imperatives) -- they are not really mismatches.
#
# TODO look at vowel positions for these? but not really in the scope of our investigation

# %% [markdown]
# ## Summary of Results

# %%
import pandas
res_df_rv_lines = pandas.read_csv("data/rv_lines.csv", keep_default_na=False)
res_df_rv_lines.head()
# Out:
#        line_no   stem stem_type root_guess variant_no  weak_only  \
# 0  01.063.02.d   iṣṇā    strong         iṣ                 False
# 1  01.063.04.b  ubhnā    strong        ubh                 False
# 2  04.019.04.c  ubhnā    strong        ubh                 False
# 3  04.018.12.d  kṣiṇā    strong        kṣi                 False
# 4  10.027.04.d  kṣiṇā    strong        kṣi                 False
#
#   attestation_texts language_period present_class  root  ...  \
# 0                           Earlier         ninth  iṣ 1  ...
# 1                V.         Earlier         ninth   ubh  ...
# 2                V.         Earlier         ninth   ubh  ...
# 3              V.B.         Earlier         ninth   kṣī  ...
# 4              V.B.         Earlier         ninth   kṣī  ...
#
#                             text_padapatha  \
# 0          púraḥ iṣṇā́si= puruhūta pūrvī́ḥ
# 1  vr̥trám yát vajrin= vr̥ṣakarman ubhnā́ḥ
# 2         dr̥ḷhā́ni aubhnāt= uśámānaḥ ójaḥ
# 3      yát prá ákṣiṇāḥ= pitáram pādagŕ̥hya
# 4     prá tám kṣiṇām= párvate-_ pādagŕ̥hya
#
#                         text_samhitapatha   meter_scansion stanza_meter  \
# 0           púra iṣṇā́si puruhūta pūrvī́ḥ   SS LLS SSLS LL   Triṣṭubh
# 1  vr̥tráṁ yád vajrin vr̥ṣakarman ubhnā́ḥ  LL L LL SSLS LL   Triṣṭubh
# 2        dr̥r̥ḷhā́ni+ aubhnād uśámāna ójo  SLLS LL SSLS LL
# 3       yát prā́kṣiṇāḥ pitáram pādagŕ̥hya   L LSL SSL LSLS   Triṣṭubh
# 4       prá táṁ kṣiṇām párvate pādagŕ̥hya  S L SL LSL LSLS   Triṣṭubh
#
#   stanza_strata strata_based_on_meter_only              stanza_late_addition  \
# 0             A                      False
# 1             A                      False
# 2             S                      False
# 3             P                      False  ['Grassmann (G)', 'Arnold (C1)']
# 4             P                      False                   ['Arnold (C1)']
#
#   hymn_absolute_no                              hymn_addressee  \
# 0               63                                       Indra
# 1               63                                       Indra
# 2              315                                       Indra
# 3              314  Dialogue Between Indra, Aditi and Vamadeva
# 4              853                                       Indra
#
#                               hymn_group
# 0  Hymns of Nodhas, Descendant of Gotama
# 1  Hymns of Nodhas, Descendant of Gotama
# 2                         Hymns to Indra
# 3                         Hymns to Indra
# 4                      The Vasukra Hymns
#
# [5 rows x 29 columns]

# %%
res_df_rv_lines \
    .groupby(["present_class", "stem_type"]) \
    .size().to_frame("count").reset_index() \
    .sort_values(["present_class", "stem_type"], ascending=[False, False])
# Out:
#   present_class stem_type  count
# 3         ninth      weak    207
# 2         ninth    strong    141
# 1         fifth      weak    271
# 0         fifth    strong    262
